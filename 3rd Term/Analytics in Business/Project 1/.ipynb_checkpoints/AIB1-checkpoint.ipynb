# %%
import pandas as pd
import numpy as np
import math 
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
subscriptions = pd.read_csv('C:/Users/jiaqi/Downloads/subscriptionsdataFINAL.csv')
#Converting to datetime
subscriptions['Join Date'] =  pd.to_datetime(subscriptions['Join Date'].str.upper(), format='%b-%y', yearfirst=False)
subscriptions['End Date'] =  pd.to_datetime(subscriptions['End Date'].str.upper(), format='%b-%y', yearfirst=False)
subscriptions
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-bee3516c70f1> in <module>
# ----> 1 subscriptions = pd.read_csv('C:/Users/jiaqi/Downloads/subscriptionsdataFINAL.csv')
#       2 #Converting to datetime
#       3 subscriptions['Join Date'] =  pd.to_datetime(subscriptions['Join Date'].str.upper(), format='%b-%y', yearfirst=False)
#       4 subscriptions['End Date'] =  pd.to_datetime(subscriptions['End Date'].str.upper(), format='%b-%y', yearfirst=False)
#       5 subscriptions
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     684     )
#     685
# --> 686     return _read(filepath_or_buffer, kwds)
#     687
#     688
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     450
#     451     # Create the parser.
# --> 452     parser = TextFileReader(fp_or_buf, **kwds)
#     453
#     454     if chunksize or iterator:
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     944             self.options["has_index_names"] = kwds["has_index_names"]
#     945
# --> 946         self._make_engine(self.engine)
#     947
#     948     def close(self):
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#    1176     def _make_engine(self, engine="c"):
#    1177         if engine == "c":
# -> 1178             self._engine = CParserWrapper(self.f, **self.options)
#    1179         else:
#    1180             if engine == "python":
#
# D:\Anaconda\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    2006         kwds["usecols"] = self.usecols
#    2007
# -> 2008         self._reader = parsers.TextReader(src, **kwds)
#    2009         self.unnamed_cols = self._reader.unnamed_cols
#    2010
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/jiaqi/Downloads/subscriptionsdataFINAL.csv'

# %%
# Graph 1: Overview of customer segments

#affluence segment overview
affluence=subscriptions.groupby(['Affluence','Subscription Type']).size().to_frame('Count').reset_index()
affluence
sns.catplot(x="Affluence", y="Count", hue="Subscription Type", kind="bar", data=affluence)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dd843027dd0f> in <module>
#       2
#       3 #affluence segment overview
# ----> 4 affluence=subscriptions.groupby(['Affluence','Subscription Type']).size().to_frame('Count').reset_index()
#       5 affluence
#       6 sns.catplot(x="Affluence", y="Count", hue="Subscription Type", kind="bar", data=affluence)
#
# NameError: name 'subscriptions' is not defined

# %%
#Age segment Overview

#Calculating Age
today = datetime.today()
subscriptions['BirthYear'] =  pd.to_datetime(subscriptions['BirthYear'], format='%Y', yearfirst=False)
subscriptions['age'] = subscriptions['BirthYear'].apply(lambda x: (today - x).days // 365)

#Calculating Age-range
bins = [18, 30, 40, 50, 60, 70, 120]
labels = ['18-29', '30-39', '40-49', '50-59', '60-69', '70+']
subscriptions['agerange'] = pd.cut(subscriptions.age, bins, labels = labels,include_lowest = True)
age=subscriptions.groupby(['agerange','Gender']).size().to_frame('Count').reset_index()

# Graph 2: Overview plot
sns.catplot(x="agerange", y="Count", hue="Gender", kind="bar", data=age)
plt.show()

# %%
date_min = min (subscriptions['Join Date'].min(),subscriptions['End Date'].min() )
date_max = max (subscriptions['Join Date'].max(),subscriptions['End Date'].max() )
dates = pd.date_range(date_min, date_max, freq = 'MS')
customers_total = pd.DataFrame({'Date':dates})
customers_total.head(), customers_total.shape
subscriptions['Duration'] = np.where(subscriptions['End Date'].isna(), 
                                     (date_max - subscriptions['Join Date']), 
                                     (subscriptions['End Date'] - subscriptions['Join Date']) )
subscriptions['Duration'] = (subscriptions['Duration'] /  np.timedelta64(1, 'M') ).apply(math.floor)

# %%
members_count =  [0] * len(dates)
def add_count(join_date,duration, dates, members_count):
    index = (dates == join_date).argmax()
    for i in range(index,index + duration+1):
        members_count[i] = members_count[i] +1 
    return members_count
subscriptions.apply(lambda row: add_count(row['Join Date'], row['Duration'],
                                          dates, members_count), axis=1)
# Out:
# 0         [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 1         [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 2         [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 3         [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 4         [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
#                                 ...
# 850028    [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 850029    [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 850030    [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 850031    [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# 850032    [699, 1203, 2309, 3082, 3714, 4584, 5420, 5837...
# Length: 850033, dtype: object

# %%
data = {"Date":dates,"Total_members":members_count}
members_count_by_month = pd.DataFrame(data)
members_count_by_month.head()
# Out:
#         Date  Total_members
# 0 2009-05-01            699
# 1 2009-06-01           1203
# 2 2009-07-01           2309
# 3 2009-08-01           3082
# 4 2009-09-01           3714

# %%
#Number of Cancellations vs time
end=subscriptions.groupby(['End Date']).size().to_frame('Count').reset_index()
cancellations = pd.concat([members_count_by_month, end], axis=1, join='inner')
#Finding percentage of cancellation each month
cancellations['pct_cancelled']= cancellations['Count'] / cancellations['Total_members']
cancellations
# Out:
#           Date  Total_members   End Date  Count  pct_cancelled
# 0   2009-05-01            699 2009-05-01     48       0.068670
# 1   2009-06-01           1203 2009-06-01     56       0.046550
# 2   2009-07-01           2309 2009-07-01    275       0.119099
# 3   2009-08-01           3082 2009-08-01    355       0.115185
# 4   2009-09-01           3714 2009-09-01    642       0.172859
# ..         ...            ...        ...    ...            ...
# 111 2018-08-01          61301 2018-08-01  12488       0.203716
# 112 2018-09-01          62702 2018-09-01  12418       0.198048
# 113 2018-10-01          62570 2018-10-01  12369       0.197683
# 114 2018-11-01          64422 2018-11-01  12336       0.191487
# 115 2018-12-01          41323 2018-12-01  12524       0.303076
#
# [116 rows x 5 columns]

# %%
#Cancellations vs Time Graph
#Graph 3
ax=sns.relplot(x="Date", y="pct_cancelled", kind="line", data=cancellations)
plt.title('Percentage Cancellations Over Time')
plt.ylabel('Percentage of member cancellations')
plt.xlabel('Time')
plt.show()

# %%
#Change in New memberships
start=subscriptions.groupby(['Join Date']).size().to_frame('Count').reset_index()
new_members = pd.concat([members_count_by_month, start], axis=1, join='inner')
new_members['pct_new_members']= new_members['Count'] / new_members['Total_members']
new_members
# Out:
#           Date  Total_members  Join Date  Count  pct_new_members
# 0   2009-05-01            699 2009-05-01    699         1.000000
# 1   2009-06-01           1203 2009-06-01    552         0.458853
# 2   2009-07-01           2309 2009-07-01   1187         0.514075
# 3   2009-08-01           3082 2009-08-01   1023         0.331927
# 4   2009-09-01           3714 2009-09-01    987         0.265751
# ..         ...            ...        ...    ...              ...
# 111 2018-08-01          61301 2018-08-01  11885         0.193879
# 112 2018-09-01          62702 2018-09-01  12360         0.197123
# 113 2018-10-01          62570 2018-10-01  12755         0.203852
# 114 2018-11-01          64422 2018-11-01  13084         0.203098
# 115 2018-12-01          41323 2018-12-01  11994         0.290250
#
# [116 rows x 5 columns]

# %%
ax=sns.relplot(x="Date", y="pct_new_members", kind="line", data=new_members)
plt.title('Percentage of New Memberships Over Time')
plt.ylabel('Percentage of New members')
plt.xlabel('Time')
plt.axvline(x='2016-01-01', linestyle='--')
plt.show()

# %%
#Changes in number of gyms
include = subscriptions[subscriptions['Join Date'].dt.year == 2015]
include.groupby(['Club']).size().to_frame('Count').reset_index()
# Out:
#                     Club  Count
# 0                 Barnet   4754
# 1                 Bexley   2787
# 2                  Brent   5364
# 3                 Camden   4541
# 4                Croydon   5038
# 5                 Ealing   4768
# 6                Enfield   3922
# 7              Greenwich   4913
# 8                Hackney    693
# 9               Haringey   4426
# 10                Harrow   4628
# 11              Havering   5565
# 12              Hounslow   4991
# 13             Islington   4794
# 14               Lambeth   4799
# 15              Lewisham   5963
# 16                Newham   5227
# 17  Richmond upon Thames   4437
# 18             Southwark   4807
# 19                Sutton   4647
# 20         Tower Hamlets   4907
# 21        Waltham Forest   5063
# 22            Wandsworth   4976
# 23           Westminster   3869

# %%
#Visitation data part 2
df2 = pd.read_csv('C:/Users/jiaqi/Downloads/visitationdataPART2.csv')
df2.head()
# Out:
#    CustomerID   visitdate TimeofVisit  peakvisits
# 0      270665  16/08/2015       19:15        True
# 1       51641  16/08/2015       19:15        True
# 2      443825  16/08/2015       19:15        True
# 3      792203  16/08/2015       19:15        True
# 4      191880  16/08/2015       19:15        True

# %%
#Visitation data part 1
df1 = pd.read_csv('C:/Users/jiaqi/Downloads/visitationdataPART1.csv')
df1.head()
# Out:
#    CustomerID   visitdate TimeofVisit  peakvisits
# 0      126444  01/05/2009       05:45       False
# 1      456610  01/05/2009       05:45       False
# 2      293763  01/05/2009       06:00       False
# 3      151253  01/05/2009       06:15       False
# 4      476569  01/05/2009       06:15       False

# %%
#Joining visitation files
visitdf = pd.concat([df1, df2], axis=0, join='inner')
#Changing vsitdate to datetime
visitdf['visitdate'] =  pd.to_datetime(visitdf['visitdate'].str.upper(), format='%d/%m/%Y', yearfirst=False)
visitdf
# Out:
#          CustomerID  visitdate TimeofVisit  peakvisits
# 0            126444 2009-05-01       05:45       False
# 1            456610 2009-05-01       05:45       False
# 2            293763 2009-05-01       06:00       False
# 3            151253 2009-05-01       06:15       False
# 4            476569 2009-05-01       06:15       False
# ...             ...        ...         ...         ...
# 1048570      443779 2015-09-27       08:45        True
# 1048571      114663 2015-09-27       08:45        True
# 1048572      290981 2015-09-27       08:45        True
# 1048573       20102 2015-09-27       08:45        True
# 1048574      433283 2015-09-27       08:45        True
#
# [2097150 rows x 4 columns]

# %%
#Merging all data into one dataframe
df4=pd.merge( left= subscriptions, right= visitdf, left_on='CustomerID', right_on='CustomerID')
df4
# Out:
#              Club  Join Date Affluence  Gender Subscription Type   End Date  \
# 0          Barnet 2015-05-01        C2    Male          Standard 2015-12-01
# 1          Barnet 2015-05-01        C2    Male          Standard 2015-12-01
# 2          Barnet 2015-05-01        C2    Male          Standard 2015-12-01
# 3          Barnet 2015-05-01        C2    Male          Standard 2015-12-01
# 4          Barnet 2015-05-01        C2    Male          Standard 2015-12-01
# ...           ...        ...       ...     ...               ...        ...
# 2097145  Havering 2014-04-01        C2  Female          Standard 2015-12-01
# 2097146  Havering 2014-04-01        C2  Female          Standard 2015-12-01
# 2097147  Havering 2014-04-01        C2  Female          Standard 2015-12-01
# 2097148  Havering 2014-04-01        C2  Female          Standard 2015-12-01
# 2097149  Havering 2014-04-01        C2  Female          Standard 2015-12-01
#
#          CustomerID  BirthYear  age agerange  Duration  visitdate TimeofVisit  \
# 0                 5 1982-01-01   39    30-39         7 2015-08-19       17:00
# 1                 5 1982-01-01   39    30-39         7 2015-08-22       08:15
# 2                 5 1982-01-01   39    30-39         7 2015-08-30       18:15
# 3                 5 1982-01-01   39    30-39         7 2015-08-31       08:45
# 4                 5 1982-01-01   39    30-39         7 2015-09-02       07:45
# ...             ...        ...  ...      ...       ...        ...         ...
# 2097145      850022 1994-01-01   27    18-29        20 2015-09-16       20:30
# 2097146      850022 1994-01-01   27    18-29        20 2015-09-17       19:45
# 2097147      850022 1994-01-01   27    18-29        20 2015-09-18       08:30
# 2097148      850022 1994-01-01   27    18-29        20 2015-09-19       11:45
# 2097149      850022 1994-01-01   27    18-29        20 2015-09-26       08:00
#
#          peakvisits
# 0             False
# 1              True
# 2              True
# 3              True
# 4              True
# ...             ...
# 2097145       False
# 2097146        True
# 2097147        True
# 2097148       False
# 2097149        True
#
# [2097150 rows x 14 columns]

# %%
# Visits vs age
dff=df4.groupby(['agerange','peakvisits']).size().to_frame('Count').reset_index()
sns.catplot(x="agerange", y="Count", hue="peakvisits", kind="bar", data=dff)
plt.show()
